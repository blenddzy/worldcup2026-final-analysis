# %% [markdown]
# # World Cup 2026 Final — Reporte de Conclusiones

# %%
from IPython.display import Markdown, Image, display
from pathlib import Path

conclusion_path = Path('../reports/conclusion.md')
if conclusion_path.exists():
    display(Markdown(conclusion_path.read_text(encoding='utf-8')))
else:
    display(Markdown('**Ejecutá primero el pipeline: `python -m src.pipeline`**'))

# %% [markdown]
# ---
# ## Visualizaciones

# %%
figures = {
    'Goal Timeline - Final': '../reports/figures/goal_timeline.png',
    'Route to Final - Spain vs Argentina': '../reports/figures/route_to_final.png',
    'Group Stage Standings': '../reports/figures/group_standings.png',
}

for title, path in figures.items():
    p = Path(path)
    if p.exists():
        display(Markdown(f'### {title}'))
        display(Image(filename=str(p)))
    else:
        display(Markdown(f'*{title}: imagen no encontrada - ejecutá el pipeline primero*'))
